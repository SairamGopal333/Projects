# %%
import csv
from datetime import date
def take_attendance():
  n = int(input("Enter number of students: "))
  with open('attendance.csv', 'a', newline='') as file:
    writer = csv.writer(file)
    for i in range(n):
      name = input("Enter name: ")
      status = input("Enter status:Present or Absent (Type P or A)")
      today = date.today()
      writer.writerow([name,today,status])
      print("Attendance saved successfully")
take_attendance()
# Out:
# Enter number of students: 5
# Enter name: Sairam
# Enter status:Present or Absent (Type P or A)P
# Attendance saved successfully
# Enter name: Alex
# Enter status:Present or Absent (Type P or A)P
# Attendance saved successfully
# Enter name: A
# Enter status:Present or Absent (Type P or A)P
# Attendance saved successfully
# Enter name: B
# Enter status:Present or Absent (Type P or A)A
# Attendance saved successfully
# Enter name: Q
# Enter status:Present or Absent (Type P or A)P
# Attendance saved successfully

# %%
with open("attendance.csv" , 'r') as file:
  print(file.read())
# Out:
# Sairam,2025-12-16,P
# Alex,2025-12-16,P
# Max,2025-12-16,A
# Lucas,2025-12-16,A
# Jesse,2025-12-16,P
# Sairam,2025-12-16,P
# Alex,2025-12-16,P
# A,2025-12-16,P
# B,2025-12-16,A
# Q,2025-12-16,P
